# %% [markdown]
# # matplotlib.pyplot

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
fig = plt.figure()
subplot = fig.add_subplot(1, 1, 1)
subplot.plot([1, 2, 3, 4])
plt.show()

# %%
fig = plt.figure()
subplot1 = fig.add_subplot(1, 2, 1)
subplot2 = fig.add_subplot(1, 2, 2)
subplot1.plot([1, 2, 3, 4])
subplot2.plot([4, 3, 2, 1])
plt.show()

# %%
fig, axes = plt.subplots(2, 2)

axes[0][0].plot([1, 2, 3, 4])
axes[0][1].plot([4, 3, 2, 1])
axes[1][0].plot([1, 2, 2, 1])
axes[1][1].plot([2, 1, 1, 2])
plt.show()

# %%
plt.plot([1, 2, 3, 4])
plt.show()

# %% [markdown]
# # 라인차트

# %%
plt.plot([2, 1, 1, 2])
plt.show()

# %%
x = [1, 2, 3, 4]
y = [1, 2, 3]
y = [1, 2, 3, 4]

plt.plot(x, y)
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 1, 1, 2])

plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("title")
plt.show()

# fig, ax = plt.subplots()
# ax.plot([1, 2, 3, 4], [2, 1, 1, 2])

# ax.set_xlabel("x-axis")
# ax.set_ylabel("y-axis")
# ax.set_title("title")

# plt.show()

# type(ax)

# %% [markdown]
# - 여러개 plot 그리기

# %%
plt.plot([1, 2, 3, 4], [1, 2, 3, 4])
plt.plot([1, 2, 3, 4], [4, 3, 2, 1])

plt.show()

# %% [markdown]
# - Label (범례) 지정

# %%
plt.plot([1, 2, 3, 4], [1, 2, 3, 4], label='ascending')
plt.plot([1, 2, 3, 4], [4, 3, 2, 1], label='descending')

plt.legend(loc='best')
plt.show()

# %%
import platform
if platform.system() == 'Darwin':
    plt.rc('font', family='AppleGothic') 
else:
    plt.rc('font', family='Malgun Gothic')

# %%
import FinanceDataReader as fdr

# %%
kospi = fdr.DataReader('KS11', '2019')
kospi.to_excel("../Finance_data/kospi.xlsx")
kospi.head()
# Out:
#                Open     High      Low    Close     Volume  Change  UpDown  \
# Date
# 2019-01-02  2050.55  2053.45  2004.27  2010.00  326367773 -0.0152       2
# 2019-01-03  2011.81  2014.72  1991.65  1993.70  427976017 -0.0081       2
# 2019-01-04  1992.40  2011.56  1984.53  2010.25  408990897  0.0083       1
# 2019-01-07  2034.24  2048.06  2030.90  2037.10  440191435  0.0134       1
# 2019-01-08  2038.68  2042.70  2023.59  2025.27  397831202 -0.0058       2
#
#              Comp         Amount            MarCap
# Date
# 2019-01-02 -31.04  4295871822881  1323645396533233
# 2019-01-03 -16.30  5358519356361  1312758913016841
# 2019-01-04  16.55  5490147620731  1323719372668579
# 2019-01-07  26.85  5301385184683  1342381870636242
# 2019-01-08 -11.83  4826641977635  1333996220969886

# %%
fig = plt.figure(figsize=(14, 6))
ax = fig.add_subplot(1, 1, 1)
ax.plot(kospi['Close'])

ax.set_xlabel("날짜")
ax.set_ylabel("코스피지수")
ax.set_title("2019년 이후 코스피지수")
plt.grid(True, axis='x')
plt.grid(True, axis='y')
plt.show()

# %% [markdown]
# ## 대출 데이터 멀티컬럼으로 불러오기

# %%
df = pd.read_excel("../Finance_data/loan.xlsx", index_col=0, header=[0, 1])
df.head()
# Out:
# 전년동월비(%)기준년월 대출고객수           대출잔액
#                 전체 1금융권 2금융권   전체  1금융권 2금융권
# '21.06         7.1  8.5  5.9  6.7   9.8  3.3
# '21.05         8.1  9.7  6.8  7.9  11.4  4.0
# '21.04         4.8  5.6  4.2  5.3   8.5  1.9
# '21.03         5.1  6.3  4.2  5.1   8.6  1.3
# '21.02         5.1  6.6  3.9  5.0   9.0  0.8

# %%
대출잔액 = df['대출잔액']
대출잔액 = 대출잔액[::-1] # 행 역순으로 읽기
대출잔액.head()
# Out:
#          전체  1금융권  2금융권
# '20.06  2.3   7.4  -2.7
# '20.07  2.0   6.9  -2.8
# '20.08  2.3   7.4  -2.7
# '20.09  2.1   6.6  -2.4
# '20.10  0.6   8.5  -7.2

# %%
대출잔액.dtypes
# Out:
# 전체      float64
# 1금융권    float64
# 2금융권    float64
# dtype: object

# %%
fig = plt.figure(figsize=(12, 8))
plt.plot(대출잔액.index, 대출잔액["전체"], marker='o', label="전체")
plt.plot(대출잔액.index, 대출잔액["1금융권"], marker='o', label="1금융권")
plt.plot(대출잔액.index, 대출잔액["2금융권"], marker='o', label="2금융권")

plt.rc("axes", unicode_minus=False)   # y축 음수처리
plt.ylabel("(전년동월비,%)")
plt.legend()
plt.grid(True, axis='y')
plt.show()

# %% [markdown]
# # 막대차트

# %%
plt.bar([1, 3, 5, 7, 9], [2, 3, 2, 2, 8])
plt.show()

# %%
kospi = pd.read_excel("../Finance_data/kospi.xlsx", index_col='Date')
kospi2020 = kospi.loc["2020"]
mean_kospi_2020 = kospi2020.resample('MS').mean()   # 월초 데이터 샘플링
mean_kospi_2020.head()
# Out:
#                    Open         High          Low        Close        Volume  \
# Date
# 2020-01-01  2207.549000  2218.408000  2192.597000  2203.442500  6.548033e+08
# 2020-02-01  2166.166000  2183.180500  2150.528500  2167.123500  6.979883e+08
# 2020-03-01  1794.281364  1824.905909  1751.699091  1786.746364  7.768648e+08
# 2020-04-01  1844.271500  1864.864000  1825.824000  1849.589000  1.052256e+09
# 2020-05-01  1963.487895  1975.821579  1949.060526  1965.174211  8.529735e+08
#
#               Change    UpDown       Comp        Amount        MarCap
# Date
# 2020-01-01 -0.001745  1.450000  -3.933000  6.434673e+12  1.482797e+15
# 2020-02-01 -0.003080  1.600000  -6.600000  7.582886e+12  1.460015e+15
# 2020-03-01 -0.004791  1.545455 -10.562273  1.009672e+13  1.203158e+15
# 2020-04-01  0.005395  1.350000   9.646000  1.080296e+13  1.243969e+15
# 2020-05-01  0.002237  1.368421   4.317895  9.957334e+12  1.320678e+15

# %%
fig = plt.figure(figsize=(15, 8))
ax = fig.add_subplot(1, 1, 1)
month = [x.strftime("%Y-%m") for x in mean_kospi_2020.index]
ax.bar(x=month, height=mean_kospi_2020['Volume'], width=0.5, color='skyblue')

plt.ticklabel_format(axis='y', style='plain')   # 지수로 표현하지 않음
plt.title("KOSPI 월별 평균 거래량 (2020년)")
plt.xlabel("월")
plt.ylabel("평균 거래량")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
ax = fig.add_subplot(1, 1, 1)
month = [x.strftime("%Y-%m") for x in mean_kospi_2020.index]
ax.barh(y=month[::-1], width=mean_kospi_2020['Volume'][::-1], height=0.5, color='#F88878')

plt.ticklabel_format(axis='x', style='plain')   # 지수로 표현하지 않음
plt.title("KOSPI 월별 평균 거래량 (2020년)")
plt.ylabel("월")
plt.xlabel("평균 거래량")
plt.show()

# %% [markdown]
# # 히스토그램

# %%
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]   # 1이 1개, 2가 2개, 3이 3개, 4가 4개
plt.hist(data)
plt.show()

# %%
data = range(100)   # 0~99
(n, bins, patches) = plt.hist(data)
plt.show()

# %%
print(n)
print(bins)
print(patches)
# Out:
# [10. 10. 10. 10. 10. 10. 10. 10. 10. 10.]
# [ 0.   9.9 19.8 29.7 39.6 49.5 59.4 69.3 79.2 89.1 99. ]
# <BarContainer object of 10 artists>

# %%
kospi = pd.read_excel("../Finance_data/kospi.xlsx", index_col='Date')
kospi.head()
# Out:
#                Open     High      Low    Close     Volume  Change  UpDown  \
# Date
# 2019-01-02  2050.55  2053.45  2004.27  2010.00  326367773 -0.0152       2
# 2019-01-03  2011.81  2014.72  1991.65  1993.70  427976017 -0.0081       2
# 2019-01-04  1992.40  2011.56  1984.53  2010.25  408990897  0.0083       1
# 2019-01-07  2034.24  2048.06  2030.90  2037.10  440191435  0.0134       1
# 2019-01-08  2038.68  2042.70  2023.59  2025.27  397831202 -0.0058       2
#
#              Comp         Amount            MarCap
# Date
# 2019-01-02 -31.04  4295871822881  1323645396533233
# 2019-01-03 -16.30  5358519356361  1312758913016841
# 2019-01-04  16.55  5490147620731  1323719372668579
# 2019-01-07  26.85  5301385184683  1342381870636242
# 2019-01-08 -11.83  4826641977635  1333996220969886

# %%
n, bins, patches = plt.hist(x=kospi['Change'] * 100, bins=20)
plt.grid()
plt.show()

# %%
print(n)
print(bins)
print(patches)
# Out:
# [  2.   0.   0.   2.   2.   7.  17.  55. 173. 434. 587. 291.  82.  16.
#    3.   0.   3.   1.   1.   1.]
# [-8.77   -7.9015 -7.033  -6.1645 -5.296  -4.4275 -3.559  -2.6905 -1.822
#  -0.9535 -0.085   0.7835  1.652   2.5205  3.389   4.2575  5.126   5.9945
#   6.863   7.7315  8.6   ]
# <BarContainer object of 20 artists>

# %% [markdown]
# # 지수화

# %%
import FinanceDataReader as fdr

sec = fdr.DataReader(symbol="005930", start="2020-01-01", end="2020-12-31")
skhynix = fdr.DataReader(symbol="000660", start="2020-01-01", end="2020-12-31")
sec.to_excel("../Finance_data/sec.xlsx")
skhynix.to_excel("../Finance_data/skhynix.xlsx")

# %%
sec = pd.read_excel("../Finance_data/sec.xlsx", index_col="Date")
skhynix = pd.read_excel("../Finance_data/skhynix.xlsx", index_col="Date")

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(1, 1, 1)
ax.plot(sec.index, sec['Close'], label="SEC")
ax.plot(sec.index, skhynix['Close'], label="SK hynix")
plt.title("삼성전자, SK하이닉스 2020년 가격 비교")
plt.legend()
plt.show()

# %%
sec_index = (sec['Close'] / sec['Close'][0]) * 100
skhynix_index = (skhynix['Close'] / skhynix['Close'][0]) * 100

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(1, 1, 1)
ax.plot(sec.index, sec_index, label="SEC")
ax.plot(sec.index, skhynix_index, label="SK hynix")
plt.ylabel("가격지수")
plt.title("삼성전자, SK하이닉스 2020년 가격지수 비교")
plt.legend()
plt.show()
# Out:
# /var/folders/56/wpml5l_5587_ysq3klw611180000gn/T/ipykernel_31780/646701586.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sec_index = (sec['Close'] / sec['Close'][0]) * 100
# /var/folders/56/wpml5l_5587_ysq3klw611180000gn/T/ipykernel_31780/646701586.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   skhynix_index = (skhynix['Close'] / skhynix['Close'][0]) * 100

# %% [markdown]
# # Candlestick

# %%
import mplfinance as mpf

# %%
df = pd.read_excel("../Finance_data/sec.xlsx", index_col=0)
df.head()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921

# %%
mpf.plot(data=df.loc["2020-12"], type='candle')

# %%
mpf.available_styles()
# Out:
# ['binance',
#  'binancedark',
#  'blueskies',
#  'brasil',
#  'charles',
#  'checkers',
#  'classic',
#  'default',
#  'ibd',
#  'kenan',
#  'mike',
#  'nightclouds',
#  'sas',
#  'starsandstripes',
#  'tradingview',
#  'yahoo']

# %% [markdown]
# - 빨간색 : 양봉 (상승)
# - 파란색 :  (하락)

# %%
mc = mpf.make_marketcolors(
    up="r", 
    down="b", 
    edge="inherit",   # 캔들의 몸통색
    wick="inherit"    # 캔들의 머리/꼬리색
)

s = mpf.make_mpf_style(
    base_mpf_style="starsandstripes", 
    marketcolors=mc, 
    gridaxis='both',   # horizontal, vertical, both
    y_on_right=True    # False는 y축을 왼쪽에 표시
)

mpf.plot(data=df.iloc[:60], type='candle', style=s, figratio=(13, 6))

# %% [markdown]
# - 막대그래프 : 거래량

# %%
mc = mpf.make_marketcolors(
    up="r", 
    down="b", 
    edge="inherit",   # 캔들의 몸통색
    wick="inherit",   # 캔들의 머리/꼬리색
    volume="inherit"  # 거래량 색상
)

s = mpf.make_mpf_style(
    base_mpf_style="starsandstripes", 
    marketcolors=mc, 
    gridaxis='both',   # horizontal, vertical, both
    y_on_right=True    # False는 y축을 왼쪽에 표시
)

mpf.plot(
    data=df.iloc[:60], 
    type='candle', 
    style=s, 
    figratio=(13, 6),
    volume=True,      # volume
    scale_width_adjustment=dict(volume=0.8, candle=1)
)

# %%
mc = mpf.make_marketcolors(
    up="r", 
    down="b", 
    edge="inherit",   # 캔들의 몸통색
    wick="inherit",   # 캔들의 머리/꼬리색
    volume="inherit"  # 거래량 색상
)

s = mpf.make_mpf_style(
    base_mpf_style="starsandstripes", 
    marketcolors=mc, 
    gridaxis='both',   # horizontal, vertical, both
    y_on_right=True    # False는 y축을 왼쪽에 표시
)

mpf.plot(
    data=df.iloc[:60], 
    type='candle',
    mav=(5, 20),   # moving average
    style=s, 
    figratio=(13, 6),
    volume=True,      # volume
    scale_width_adjustment=dict(volume=0.8, candle=1)
)

# %% [markdown]
# # 이동평균선

# %%
kospi = pd.read_excel("../Finance_data/kospi.xlsx", index_col=0)
kospi.head()
# Out:
#                Open     High      Low    Close     Volume  Change  UpDown  \
# Date
# 2019-01-02  2050.55  2053.45  2004.27  2010.00  326367773 -0.0152       2
# 2019-01-03  2011.81  2014.72  1991.65  1993.70  427976017 -0.0081       2
# 2019-01-04  1992.40  2011.56  1984.53  2010.25  408990897  0.0083       1
# 2019-01-07  2034.24  2048.06  2030.90  2037.10  440191435  0.0134       1
# 2019-01-08  2038.68  2042.70  2023.59  2025.27  397831202 -0.0058       2
#
#              Comp         Amount            MarCap
# Date
# 2019-01-02 -31.04  4295871822881  1323645396533233
# 2019-01-03 -16.30  5358519356361  1312758913016841
# 2019-01-04  16.55  5490147620731  1323719372668579
# 2019-01-07  26.85  5301385184683  1342381870636242
# 2019-01-08 -11.83  4826641977635  1333996220969886

# %%
kospi["MA20"] = kospi['Close'].rolling(window=20).mean()
kospi["MA60"] = kospi['Close'].rolling(window=60).mean()
kospi["MA120"] = kospi['Close'].rolling(window=120).mean()
kospi.head()
# Out:
#                Open     High      Low    Close     Volume  Change  UpDown  \
# Date
# 2019-01-02  2050.55  2053.45  2004.27  2010.00  326367773 -0.0152       2
# 2019-01-03  2011.81  2014.72  1991.65  1993.70  427976017 -0.0081       2
# 2019-01-04  1992.40  2011.56  1984.53  2010.25  408990897  0.0083       1
# 2019-01-07  2034.24  2048.06  2030.90  2037.10  440191435  0.0134       1
# 2019-01-08  2038.68  2042.70  2023.59  2025.27  397831202 -0.0058       2
#
#              Comp         Amount            MarCap  MA20  MA60  MA120
# Date
# 2019-01-02 -31.04  4295871822881  1323645396533233   NaN   NaN    NaN
# 2019-01-03 -16.30  5358519356361  1312758913016841   NaN   NaN    NaN
# 2019-01-04  16.55  5490147620731  1323719372668579   NaN   NaN    NaN
# 2019-01-07  26.85  5301385184683  1342381870636242   NaN   NaN    NaN
# 2019-01-08 -11.83  4826641977635  1333996220969886   NaN   NaN    NaN

# %% [markdown]
# # 데이터프레임과 시각화
